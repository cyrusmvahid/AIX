# %%
import matplotlib.pyplot as plt
from PIL import Image
import os, json
from skimage.segmentation import slic
from torchvision import transforms, models
import torch.nn.functional as F

import torch
import numpy as np

# %%
def get_image(path):
    with open(os.path.abspath(path), 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB')

# %%
img = get_image('data/cheetah3.png')
plt.imshow(img)
type(img)
# Out:
# PIL.Image.Image

# %%
#img.thumbnail((224,224))
#plt.imshow(img)
resize = transforms.Resize((224,224))
img = resize(img)
plt.imshow(img)

# %%
to_tensor = transforms.ToTensor()
to_tensor(img).shape
# Out:
# torch.Size([3, 224, 224])

# %%
segments_slic = slic(img, n_segments=50, compactness=30, sigma=3)
segments_slic.shape
# Out:
# (224, 224)

# %%
# resize and take the center part of image to what our model expects
def get_input_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])       
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])    

    return transf

def get_input_tensors(img):
    transf = get_input_transform()
    # unsqeeze converts single image to batch of 1
    return transf(img).unsqueeze(0)

# %%
#img_orig = to_tensor(img)
#img_orig = torch.permute(img_orig, (2,1,0))
img_original = get_input_tensors(img)
img_orig = img_original.squeeze()

img_original.shape, to_tensor(img).shape
# Out:
# (torch.Size([1, 3, 224, 224]), torch.Size([3, 224, 224]))

# %%
model = models.vgg16(pretrained=True)
model = models.inception_v3(pretrained=True)

# %%
global_probs = 0
def batch_predict_t(images):
    print("==================inside batch_predict_t==================")
    model.eval()
    images = torch.from_numpy(images)
    images = [images]
    batch = torch.stack(tuple(i for i in images), dim=0)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    batch = batch.to(device)
    
    logits = model(batch)
    probs = F.softmax(logits, dim=1)
    global_probs = probs.shape
    print("==================outside batch_predict_t==================")
    return probs.detach().cpu().numpy()

# %%
#test_pred_t = batch_predict_t(img_orig.numpy())
#test_pred_t.shape

# %%
# define a function that depends on a binary mask representing if an image region is hidden
def mask_image(zs, segmentation, image, background=None):
    if background is None:
        background = image.mean((0,1))
    out = np.zeros((zs.shape[0], image.shape[0], image.shape[1], image.shape[2]))
    for i in range(zs.shape[0]):
        out[i,:,:,:] = image
        for j in range(zs.shape[1]):
            if zs[i,j] == 0:
                out[i][segmentation == j,:] = background
    return out

# %%
torch.permute(img_orig, (2,1,0)).shape
# Out:
# torch.Size([224, 224, 3])

# %%
type(segments_slic), segments_slic.shape, type(img_orig), img_orig.shape
# Out:
# (numpy.ndarray, (224, 224), torch.Tensor, torch.Size([3, 224, 224]))

# %%
def get_preprocess_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])     
    transf = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])    

    return transf

# %%
preprocess_image = get_preprocess_transform()
preprocess_image(img).shape
# Out:
# torch.Size([3, 224, 224])

# %%
img_t = get_input_tensors(img)
model.eval()
logits = model(img_t)

# %%
test_pred_t = batch_predict_t(img_orig.numpy())
test_pred_t.argmax()
# Out:
# ==================inside batch_predict_t==================
# ==================outside batch_predict_t==================
# 293

# %%
masked_image = mask_image(zs=np.zeros((1,50)), 
                          segmentation=segments_slic, 
                          image=torch.permute(img_orig, (2,1,0)), 
                          background=255).squeeze()
masked_image = np.transpose(masked_image, (2,0,1))
masked_image = np.float32(masked_image)
masked_image.shape, img_orig.numpy().shape
type(masked_image[0][0][0]), type(img_orig.numpy()[0][0][0])
# Out:
# (numpy.float32, numpy.float32)

# %%
test_pred_m = batch_predict_t(masked_image)
# Out:
# ==================inside batch_predict_t==================
# ==================outside batch_predict_t==================

# %%
np.array(np.where(test_pred_m[0] != 0)).shape
# Out:
# (1, 1000)

# %%
import shap

# %%
explainer = shap.KernelExplainer(batch_predict_t, masked_image)
# Out:
# ==================inside batch_predict_t==================
# ==================outside batch_predict_t==================

# %%
global_probs
# Out:
# 0

# %%
shap_values = explainer.shap_values(np.ones((1,50)), nsamples=1000, verbose=True) # runs VGG16 1000 times
